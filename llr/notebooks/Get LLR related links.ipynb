# %% [markdown]
# In this notebook we generate related links for pages using functional data (what people view on GOV.UK), and LLR (the Log-Likelihood Ratio).
#
# LLR (log likelihood ratio) looks at how often pages A and B are viewed together, but also how often in general each page is viewed (if page A co-occurs at similar rates with B and C, but C is less popular sitewide, it is seen as a more relevant recommendation for A).
#
# A blog about LLR: http://tdunning.blogspot.com/2008/03/surprise-and-coincidence.html
# Paper: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.14.5962&rep=rep1&type=pdf
#
#
# Some notes on what we do:
# - LLR by content ID
# - look at page hits sequentially - link page viewed AFTER page
# - filter out "finding' pages - `document_type` in ['document_collection', 'finder', 'homepage', 'license_finder', 'mainstream_browse_page', 'organisation', 'search', 'service_manual_homepage', 'service_manual_topic', 'services_and_information', 'taxon', 'topic', 'topical_event']
# - filter out 'fatality_notice', 'contact', 'service_sign_in','html_publication', 'calculator', 'completed_transaction' `document_type`s
# - filter out embedded links that already exist on pages

# %% [markdown]
# # Setup

# %%
import os 
import math
from ast import literal_eval
import pandas as pd

# %%
# set up pandas, bigquery, data dir stuff
ProjectID = 'govuk-bigquery-analytics'
KEY_DIR = os.getenv("BQ_KEY_DIR")
key_file_path = os.path.join(KEY_DIR, os.listdir(KEY_DIR)[0])

DATA_DIR = os.getenv("DATA_DIR")

# %% [markdown]
# # Run LLR Query
# Node2Vec used 3 weeks of data, so we should use 3 weeks here to give it the same chance of capturing the functional network
#
# The query dequencs pageviews using hitNumber, so we look at pages viewed *after* other pages
#
# You have to sub in `START_DATE` and `END_DATE`

# %%
file_object  = open('../queries/llr_pages_content_id_split_up_hitNumber.sql', 'r')
QUERY = file_object.read()

# %%
print(QUERY)
# Out:
# WITH
#   session_pages AS (
#   SELECT
#     CONCAT(fullVisitorId,"-",CAST(visitId AS STRING)) AS sessionId,
#     content_id,
#     min(hitNumber) as hitNumber
#   FROM (
#     SELECT
#       fullVisitorId,
#       visitId,
#       hits.hitNumber as hitNumber,
#       hits.page.pagePath AS pagePath,
#       (
#       SELECT
#         value
#       FROM
#         hits.customDimensions
#       WHERE
#         index=4) AS content_id,
#       (
#       SELECT
#         value
#       FROM
#         hits.customDimensions
#       WHERE
#         index=2) AS document_type
#     FROM
#       `govuk-bigquery-analytics.87773428.ga_sessions_*` AS sessions
#     CROSS JOIN
#       UNNEST(sessions.hits) AS hits
#     WHERE
#       _TABLE_SUFFIX BETWEEN '{START_DATE}'
#       AND '{END_DATE}')
#   WHERE
#     pagePath != '/'
#     AND document_type NOT IN ('document_collection',
#       'finder',
#       'homepage',
#       'license_finder',
#       'mainstream_browse_page',
#       'organisation',
#       'search',
#       'service_manual_homepage',
#       'service_manual_topic',
#       'services_and_information',
#       'taxon',
#       'topic',
#       'topical_event',
#       -- filter out fatality notices here
#       'fatality_notice',
#       -- filter out contact pages
#       'contact',
#       -- filter out service sign in pages
#       'service_sign_in',
#       -- filter out html publications? instead of recommending https://www.gov.uk/government/publications/rates-and-allowances-national-insurance-contributions/rates-and-allowances-national-insurance-contributions
#       -- should we be recommending https://www.gov.uk/government/publications/rates-and-allowances-national-insurance-contributions ?
#       'html_publication',
#       -- exclude calculator pages like https://www.gov.uk/child-benefit-tax-calculator/main ?
#       'calculator',
#       -- exclude completed transactions like
#       'completed_transaction')
#     AND content_id NOT IN ('00000000-0000-0000-0000-000000000000',
#       '[object Object]')
#   GROUP BY
#     sessionId,
#     content_id),
#   co_occurrences_table AS (
#   SELECT
#       session_pages_1.content_id AS page_1,
#       session_pages_2.content_id AS page_2,
#       COUNT(DISTINCT session_pages_1.sessionId) AS co_occurrences
#     FROM
#       session_pages session_pages_1
#     JOIN
#       session_pages session_pages_2
#     ON
#       session_pages_1.sessionId = session_pages_2.sessionId
#     WHERE
#       session_pages_1.content_id != session_pages_2.content_id
#       AND session_pages_1.hitNumber < session_pages_2.hitNumber
#     GROUP BY
#       page_1,
#       page_2
#     ),
#   occurrences_per_page_1 AS (
#   SELECT
#     page_1,
#     SUM(co_occurrences) AS page_1_occurrences
#   FROM
#     co_occurrences_table
#   GROUP BY
#     page_1
#     ),
#   occurrences_per_page_2 AS (
#   SELECT
#     page_2,
#     SUM(co_occurrences) AS page_2_occurrences
#   FROM
#     co_occurrences_table
#   GROUP BY
#     page_2
#     ),
#   -- total_occurrences_table AS (
#   -- SELECT
#   --   SUM(co_occurrences) AS total_occurrences
#   -- FROM
#   --   co_occurrences_table
#   --   ),
#   occurrence_counts AS (
#   SELECT
#     co_occ.page_1,
#     co_occ.page_2,
#     co_occ.co_occurrences,
#     occ_per_page_1.page_1_occurrences page_1_occurrences,
#     occ_per_page_2.page_2_occurrences AS page_2_occurrences,
#     (SELECT
#     SUM(co_occurrences)
#   FROM
#     co_occurrences_table
#     ) AS total_occurrences
#   FROM co_occurrences_table AS co_occ
#   JOIN occurrences_per_page_1 occ_per_page_1
#   ON co_occ.page_1 = occ_per_page_1.page_1
#   JOIN occurrences_per_page_2 occ_per_page_2
#   ON co_occ.page_2 = occ_per_page_2.page_2
#     --  WHERE co_occurrences > 1
#     ),
#   llr_scores AS (
#   SELECT
#     page_1,
#     page_2,
#     k11,
#     page_1_occurrences,
#     -- k12,
#     -- k21,
#     -- k22,
#     -- N,
#     -- k11_k21,
#     -- k11_k12,
#     -- k21_k22,
#     -- k12_k22,
#     -- H_k,
#     -- H_rowsums_k,
#     -- H_colsums_k,
#     2*N*(H_k - H_rowsums_k - H_colsums_k) AS llr_score
#   FROM (
#     SELECT
#       page_1,
#       page_2,
#       k11,
#       -- k12,
#       -- k21,
#       -- k22,
#       N,
#       k11_k21 AS page_1_occurrences,
#       -- k11_k12,
#       -- k21_k22,
#       -- k12_k22,
#       IF(k11>0,
#         k11*LOG(k11/N),
#         0) + IF(k12>0,
#         k12*LOG(k12/N),
#         0) + IF(k21>0,
#         k21*LOG(k21/N),
#         0) + IF(k22>0,
#         k22*LOG(k22/N),
#         0) AS H_k,
#       k11_k12*LOG(k11_k12/N) + k21_k22*LOG(k21_k22/N) AS H_rowsums_k,
#       k11_k21*LOG(k11_k21/N) + k12_k22*LOG(k12_k22/N) AS H_colsums_k
#     FROM (
#       SELECT
#         page_1,
#         page_2,
#         co_occurrences AS k11,
#         page_1_occurrences AS k11_k21,
#         page_2_occurrences AS k11_k12,
#         page_2_occurrences - co_occurrences AS k12,
#         page_1_occurrences - co_occurrences AS k21,
#         total_occurrences - page_2_occurrences - page_1_occurrences + co_occurrences AS k22,
#         total_occurrences - page_2_occurrences AS k21_k22,
#         total_occurrences - page_1_occurrences AS k12_k22,
#         total_occurrences AS N
#       FROM
#         occurrence_counts ) ) )
#   -- query to output a few ranked links per link
# SELECT
#   page_1,
#   page_2,
#   page_1_occurrences,
#   co_occurrences,
#   llr_score,
#   rank
# FROM (
#   SELECT
#     page_1,
#     page_2,
#     page_1_occurrences,
#     k11 AS co_occurrences,
#     llr_score,
#     RANK() OVER (PARTITION BY page_1 ORDER BY CAST(llr_score AS numeric) DESC) AS rank
#   FROM
#     llr_scores )
# WHERE
#   rank < 101
# ORDER BY
#   page_1,
#   rank

# %%
print(QUERY.format(START_DATE='20190215', END_DATE='20190307'))
# Out:
# WITH
#   session_pages AS (
#   SELECT
#     CONCAT(fullVisitorId,"-",CAST(visitId AS STRING)) AS sessionId,
#     content_id,
#     min(hitNumber) as hitNumber
#   FROM (
#     SELECT
#       fullVisitorId,
#       visitId,
#       hits.hitNumber as hitNumber,
#       hits.page.pagePath AS pagePath,
#       (
#       SELECT
#         value
#       FROM
#         hits.customDimensions
#       WHERE
#         index=4) AS content_id,
#       (
#       SELECT
#         value
#       FROM
#         hits.customDimensions
#       WHERE
#         index=2) AS document_type
#     FROM
#       `govuk-bigquery-analytics.87773428.ga_sessions_*` AS sessions
#     CROSS JOIN
#       UNNEST(sessions.hits) AS hits
#     WHERE
#       _TABLE_SUFFIX BETWEEN '20190215'
#       AND '20190307')
#   WHERE
#     pagePath != '/'
#     AND document_type NOT IN ('document_collection',
#       'finder',
#       'homepage',
#       'license_finder',
#       'mainstream_browse_page',
#       'organisation',
#       'search',
#       'service_manual_homepage',
#       'service_manual_topic',
#       'services_and_information',
#       'taxon',
#       'topic',
#       'topical_event',
#       -- filter out fatality notices here
#       'fatality_notice',
#       -- filter out contact pages
#       'contact',
#       -- filter out service sign in pages
#       'service_sign_in',
#       -- filter out html publications? instead of recommending https://www.gov.uk/government/publications/rates-and-allowances-national-insurance-contributions/rates-and-allowances-national-insurance-contributions
#       -- should we be recommending https://www.gov.uk/government/publications/rates-and-allowances-national-insurance-contributions ?
#       'html_publication',
#       -- exclude calculator pages like https://www.gov.uk/child-benefit-tax-calculator/main ?
#       'calculator',
#       -- exclude completed transactions like
#       'completed_transaction')
#     AND content_id NOT IN ('00000000-0000-0000-0000-000000000000',
#       '[object Object]')
#   GROUP BY
#     sessionId,
#     content_id),
#   co_occurrences_table AS (
#   SELECT
#       session_pages_1.content_id AS page_1,
#       session_pages_2.content_id AS page_2,
#       COUNT(DISTINCT session_pages_1.sessionId) AS co_occurrences
#     FROM
#       session_pages session_pages_1
#     JOIN
#       session_pages session_pages_2
#     ON
#       session_pages_1.sessionId = session_pages_2.sessionId
#     WHERE
#       session_pages_1.content_id != session_pages_2.content_id
#       AND session_pages_1.hitNumber < session_pages_2.hitNumber
#     GROUP BY
#       page_1,
#       page_2
#     ),
#   occurrences_per_page_1 AS (
#   SELECT
#     page_1,
#     SUM(co_occurrences) AS page_1_occurrences
#   FROM
#     co_occurrences_table
#   GROUP BY
#     page_1
#     ),
#   occurrences_per_page_2 AS (
#   SELECT
#     page_2,
#     SUM(co_occurrences) AS page_2_occurrences
#   FROM
#     co_occurrences_table
#   GROUP BY
#     page_2
#     ),
#   -- total_occurrences_table AS (
#   -- SELECT
#   --   SUM(co_occurrences) AS total_occurrences
#   -- FROM
#   --   co_occurrences_table
#   --   ),
#   occurrence_counts AS (
#   SELECT
#     co_occ.page_1,
#     co_occ.page_2,
#     co_occ.co_occurrences,
#     occ_per_page_1.page_1_occurrences page_1_occurrences,
#     occ_per_page_2.page_2_occurrences AS page_2_occurrences,
#     (SELECT
#     SUM(co_occurrences)
#   FROM
#     co_occurrences_table
#     ) AS total_occurrences
#   FROM co_occurrences_table AS co_occ
#   JOIN occurrences_per_page_1 occ_per_page_1
#   ON co_occ.page_1 = occ_per_page_1.page_1
#   JOIN occurrences_per_page_2 occ_per_page_2
#   ON co_occ.page_2 = occ_per_page_2.page_2
#     --  WHERE co_occurrences > 1
#     ),
#   llr_scores AS (
#   SELECT
#     page_1,
#     page_2,
#     k11,
#     page_1_occurrences,
#     -- k12,
#     -- k21,
#     -- k22,
#     -- N,
#     -- k11_k21,
#     -- k11_k12,
#     -- k21_k22,
#     -- k12_k22,
#     -- H_k,
#     -- H_rowsums_k,
#     -- H_colsums_k,
#     2*N*(H_k - H_rowsums_k - H_colsums_k) AS llr_score
#   FROM (
#     SELECT
#       page_1,
#       page_2,
#       k11,
#       -- k12,
#       -- k21,
#       -- k22,
#       N,
#       k11_k21 AS page_1_occurrences,
#       -- k11_k12,
#       -- k21_k22,
#       -- k12_k22,
#       IF(k11>0,
#         k11*LOG(k11/N),
#         0) + IF(k12>0,
#         k12*LOG(k12/N),
#         0) + IF(k21>0,
#         k21*LOG(k21/N),
#         0) + IF(k22>0,
#         k22*LOG(k22/N),
#         0) AS H_k,
#       k11_k12*LOG(k11_k12/N) + k21_k22*LOG(k21_k22/N) AS H_rowsums_k,
#       k11_k21*LOG(k11_k21/N) + k12_k22*LOG(k12_k22/N) AS H_colsums_k
#     FROM (
#       SELECT
#         page_1,
#         page_2,
#         co_occurrences AS k11,
#         page_1_occurrences AS k11_k21,
#         page_2_occurrences AS k11_k12,
#         page_2_occurrences - co_occurrences AS k12,
#         page_1_occurrences - co_occurrences AS k21,
#         total_occurrences - page_2_occurrences - page_1_occurrences + co_occurrences AS k22,
#         total_occurrences - page_2_occurrences AS k21_k22,
#         total_occurrences - page_1_occurrences AS k12_k22,
#         total_occurrences AS N
#       FROM
#         occurrence_counts ) ) )
#   -- query to output a few ranked links per link
# SELECT
#   page_1,
#   page_2,
#   page_1_occurrences,
#   co_occurrences,
#   llr_score,
#   rank
# FROM (
#   SELECT
#     page_1,
#     page_2,
#     page_1_occurrences,
#     k11 AS co_occurrences,
#     llr_score,
#     RANK() OVER (PARTITION BY page_1 ORDER BY CAST(llr_score AS numeric) DESC) AS rank
#   FROM
#     llr_scores )
# WHERE
#   rank < 101
# ORDER BY
#   page_1,
#   rank

# %%
df_llr_recs = pd.io.gbq.read_gbq(
    QUERY.format(START_DATE='20190218', END_DATE='20190310'),
                           project_id=ProjectID,
                           reauth=False,
                           verbose=True,
                           private_key=key_file_path,
                           dialect='standard')
# Out:
# /Users/suganyasivaskantharajah/.virtualenvs/llr_links/lib/python3.7/site-packages/pandas/io/gbq.py:149: FutureWarning: verbose is deprecated and will be removed in a future version. Set logging level in order to vary verbosity
#   credentials=credentials, verbose=verbose, private_key=private_key)
# /Users/suganyasivaskantharajah/.virtualenvs/llr_links/lib/python3.7/site-packages/pandas/io/gbq.py:149: FutureWarning: private_key is deprecated and will be removed in a future version.Use the credentials argument instead. See https://pandas-gbq.readthedocs.io/en/latest/howto/authentication.html for examples on using the credentials argument with service account keys.
#   credentials=credentials, verbose=verbose, private_key=private_key)

# %%
df_llr_recs.to_csv(os.path.join(DATA_DIR, 'llr', 'llr_recs_20190218_20190310.csv.gz'),
                     compression='gzip', index=False)

# %%
df_llr_recs.head()
# Out:
#                                  page_1                                page_2  \
# 0  00015d3f-e7d9-48e8-95ff-ac3f7fa07be3  8ec6ea6e-a259-459a-9e5e-ffab399a2e2e
# 1  000227a8-f0d2-417d-8ce4-27a18d62d442  f79797b8-93a8-4826-a3fa-91488bfbb73d
# 2  000227a8-f0d2-417d-8ce4-27a18d62d442  60556764-7631-11e4-a3cb-005056011aef
# 3  000227a8-f0d2-417d-8ce4-27a18d62d442  bd3dad18-b6ed-4f4c-b2d4-1cd4caa9faa8
# 4  000227a8-f0d2-417d-8ce4-27a18d62d442  5fe61962-7631-11e4-a3cb-005056011aef
#
#    page_1_occurrences  co_occurrences     llr_score  rank
# 0                   1               1  7.788324e+08     1
# 1                  30               1  1.272172e+09     1
# 2                  30               1  1.266232e+09     2
# 3                  30               1  1.263362e+09     3
# 4                  30               1  1.263362e+09     3

# %% [markdown]
# Quite a big DF at the moment, as I've taken up to 100 links for each page, only because I don't know how many will be filtered out by removing embedded links. I've also looked at pages over 3 weeks, so the number of occurrences for each page will be fairly high

# %%
print(df_llr_recs.shape)
print(df_llr_recs[df_llr_recs['page_1_occurrences']>1].shape)
print(df_llr_recs[df_llr_recs['page_1_occurrences']>10].shape)
print(df_llr_recs[df_llr_recs['page_1_occurrences']>100].shape)
# Out:
# (4923663, 6)
# (4907923, 6)
# (4706298, 6)
# (2906420, 6)

# %% [markdown]
# # Get top n related links, without embedded links
# Filter out embedded links that already exist in pages, and get the top n related links for each page

# %% [markdown]
# ## Get embedded links
# Get the embedded links for each page from `content_json_extended.csv.gz` (created in [govuk-network-embedding](https://github.com/alphagov/govuk-network-embedding/blob/2nd-iteration/notebooks/data_extract/extract_links_from_json.ipynb)

# %%
content_json_file = os.path.join(DATA_DIR, 'content_api', "11-02-19", "
                                 .csv.gz")
content = pd.read_csv(content_json_file, compression="gzip")

# %%
content.columns
# Out:
# Index(['base_path', 'body', 'children', 'collection_links', 'content_id',
#        'description', 'document_collections', 'document_type',
#        'embedded_links', 'field_of_operation', 'finder', 'first_published_at',
#        'lead_organisations', 'locale', 'mainstream_browse_pages', 'ministers',
#        'ordered_related_items_overrides', 'organisations',
#        'pages_part_of_step_nav', 'pages_related_to_step_nav', 'parent',
#        'part_of_step_navs', 'people', 'policy_areas',
#        'primary_publishing_organisation', 'publishing_app', 'related_guides',
#        'related_links', 'related_mainstream', 'related_mainstream_content',
#        'related_policies', 'related_statistical_data_sets',
#        'related_to_step_navs', 'roles', 'sections', 'speaker', 'title',
#        'topical_events', 'topics'],
#       dtype='object')

# %%
content_base_cid = dict(zip(content.base_path, content.content_id))

# %%
content['embedded_links'] = content['embedded_links'].map(literal_eval)

content['embedded_cids'] = content['embedded_links'].map(lambda x: [content_base_cid[l] for l in x 
                                                                    if l in content_base_cid.keys()])

# %%
cid_link_cids = dict(zip(content.content_id, content.embedded_cids))

# %%
cid_link_cids_with_emb = {k: v for k, v in cid_link_cids.items() if len(v) > 0}

# %%
len(cid_link_cids_with_emb.keys())
# Out:
# 2236

# %% [markdown]
# ## Get titles and base paths
# For each content ID get its title and base_path from `content_json_extended.csv.gz` so that humans can assess our links

# %%
cids_titles = dict(zip(content.content_id, content.title))

# %%
cids_paths = dict(zip(content.content_id, content.base_path))

# %%
df_llr_recs.head()
# Out:
#                                  page_1                                page_2  \
# 0  00015d3f-e7d9-48e8-95ff-ac3f7fa07be3  8ec6ea6e-a259-459a-9e5e-ffab399a2e2e
# 1  000227a8-f0d2-417d-8ce4-27a18d62d442  f79797b8-93a8-4826-a3fa-91488bfbb73d
# 2  000227a8-f0d2-417d-8ce4-27a18d62d442  60556764-7631-11e4-a3cb-005056011aef
# 3  000227a8-f0d2-417d-8ce4-27a18d62d442  bd3dad18-b6ed-4f4c-b2d4-1cd4caa9faa8
# 4  000227a8-f0d2-417d-8ce4-27a18d62d442  5fe61962-7631-11e4-a3cb-005056011aef
#
#    page_1_occurrences  co_occurrences     llr_score  rank
# 0                   1               1  7.788324e+08     1
# 1                  30               1  1.272172e+09     1
# 2                  30               1  1.266232e+09     2
# 3                  30               1  1.263362e+09     3
# 4                  30               1  1.263362e+09     3

# %% [markdown]
# Create a dictionary `related_links` from `df_llr_recs`, the content IDs of each page are the keys, the values are arrays of the recommended links, with LLR scores, ranks fro the SQL, and co_occurrence counts

# %%
related_links = {}

for row in df_llr_recs.itertuples():
    if row[1] not in related_links:
        related_links[row[1]] = list()
    related_links[row[1]].append (
        {'link': row[2], 'llr_score': row[5], 'rank': row[6], 'co_occurrences': row[4]})

# %%
def get_page_title(content_id):
    try:
        return cids_titles[content_id]
    except KeyError:
        return 'unknown'

def get_page_url(content_id):
    try:
        return f"www.gov.uk{cids_paths[content_id]}"
    except KeyError:
        return 'unknown'

# %% [markdown]
# ## Remove embedded links
# With a dictionary of content IDs : related links, and a dictionary of content IDs : embedded links, filter out all embedded links that occur in related links for each content ID

# %%
def remove_embedded(related_links_dict, cid_link_cids_with_emb):
    for content_id, embedded_links in cid_link_cids_with_emb.items():
        for emb_link in embedded_links:
            try:
                related_links_dict[content_id] = [rec for rec in related_links_dict[content_id] if rec['link'] != emb_link]
            except KeyError:
                continue

# %%
remove_embedded(related_links, cid_link_cids_with_emb)

# %% [markdown]
# ## Get top n, add titles and base paths
# Using a clean dictionary of related links (no replication of embedded links), iterate through the dictionary:
#  - sort the recommended related links by their rank, and take the top n
#  - add titles and base paths for the pages and their related links
#  - return a DataFrame with all this info

# %%
def get_top_n(related_links_dict, n=10):
    pages_links = []
    for page, recs in related_links_dict.items():
        title = get_page_title(page)
        base_path = get_page_url(page)
        sorted_recs = sorted(recs, key=lambda k: k['rank'])[:n]
        for rec in sorted_recs:
            page_link = {"title": title,
                         "link_title": get_page_title(rec['link']),
                         "base_path": base_path,
                         "link_base_path": get_page_url(rec['link']),
                         "page": page}
            page_link.update(rec)
            pages_links.append(page_link)
    return pd.DataFrame(pages_links)

# %%
top_10_df = get_top_n(related_links, n=10)

# %%
top_10_df
# Out:
#                                                  base_path  co_occurrences  \
# 0        www.gov.uk/government/statistics/uk-consumer-p...               1
# 1        www.gov.uk/government/publications/foi-respons...               1
# 2        www.gov.uk/government/publications/foi-respons...               1
# 3        www.gov.uk/government/publications/foi-respons...               1
# 4        www.gov.uk/government/publications/foi-respons...               1
# 5        www.gov.uk/government/publications/foi-respons...               1
# 6        www.gov.uk/government/publications/foi-respons...               1
# 7        www.gov.uk/government/publications/foi-respons...               1
# 8        www.gov.uk/government/publications/foi-respons...               1
# 9        www.gov.uk/government/publications/foi-respons...               1
# 10       www.gov.uk/government/publications/foi-respons...               1
# 11                                                 unknown               2
# 12                                                 unknown               2
# 13                                                 unknown               2
# 14                                                 unknown               2
# 15                                                 unknown               2
# 16                                                 unknown               2
# 17                                                 unknown               2
# 18                                                 unknown               2
# 19                                                 unknown               2
# 20                                                 unknown               2
# 21                                                 unknown               1
# 22                                                 unknown               1
# 23                                                 unknown               2
# 24                                                 unknown               2
# 25                                                 unknown               1
# 26                                                 unknown               1
# 27                                                 unknown               1
# 28                                                 unknown               1
# 29                                                 unknown               1
# ...                                                    ...             ...
# 1081307  www.gov.uk/employment-tribunal-decisions/mrs-a...               1
# 1081308  www.gov.uk/employment-tribunal-decisions/mrs-a...               1
# 1081309  www.gov.uk/employment-tribunal-decisions/mrs-a...               1
# 1081310  www.gov.uk/employment-tribunal-decisions/mrs-a...               1
# 1081311  www.gov.uk/employment-tribunal-decisions/mrs-a...               1
# 1081312  www.gov.uk/employment-tribunal-decisions/mrs-a...               1
# 1081313  www.gov.uk/employment-tribunal-decisions/mrs-a...               1
# 1081314  www.gov.uk/employment-tribunal-decisions/mrs-a...               1
# 1081315  www.gov.uk/employment-tribunal-decisions/mrs-a...               1
# 1081316  www.gov.uk/employment-tribunal-decisions/mrs-a...               1
# 1081317  www.gov.uk/government/publications/sp11-7ef-en...               1
# 1081318  www.gov.uk/government/publications/sp11-7ef-en...               1
# 1081319  www.gov.uk/government/publications/sp11-7ef-en...               1
# 1081320  www.gov.uk/government/publications/sp11-7ef-en...               1
# 1081321  www.gov.uk/government/publications/sp11-7ef-en...               1
# 1081322  www.gov.uk/government/publications/sp11-7ef-en...               1
# 1081323  www.gov.uk/government/publications/sp11-7ef-en...               1
# 1081324  www.gov.uk/government/publications/sp11-7ef-en...               1
# 1081325  www.gov.uk/government/publications/sp11-7ef-en...               1
# 1081326  www.gov.uk/government/publications/sp11-7ef-en...               1
# 1081327  www.gov.uk/government/publications/cross-count...               8
# 1081328  www.gov.uk/government/publications/cross-count...               8
# 1081329  www.gov.uk/government/publications/cross-count...               8
# 1081330  www.gov.uk/government/publications/cross-count...               7
# 1081331  www.gov.uk/government/publications/cross-count...               8
# 1081332  www.gov.uk/government/publications/cross-count...               7
# 1081333  www.gov.uk/government/publications/cross-count...               7
# 1081334  www.gov.uk/government/publications/cross-count...               7
# 1081335  www.gov.uk/government/publications/cross-count...               7
# 1081336  www.gov.uk/government/publications/cross-count...               6
#
#                                          link  \
# 0        8ec6ea6e-a259-459a-9e5e-ffab399a2e2e
# 1        f79797b8-93a8-4826-a3fa-91488bfbb73d
# 2        60556764-7631-11e4-a3cb-005056011aef
# 3        bd3dad18-b6ed-4f4c-b2d4-1cd4caa9faa8
# 4        5fe61962-7631-11e4-a3cb-005056011aef
# 5        5feec55f-7631-11e4-a3cb-005056011aef
# 1081311  fffda3d7-37ec-4fff-b643-a53261df918f     5
# 1081312  fffda3d7-37ec-4fff-b643-a53261df918f     6
# 1081313  fffda3d7-37ec-4fff-b643-a53261df918f     7
# 1081314  fffda3d7-37ec-4fff-b643-a53261df918f     7
# 1081315  fffda3d7-37ec-4fff-b643-a53261df918f     9
# 1081316  fffda3d7-37ec-4fff-b643-a53261df918f    10
# 1081317  fffe698b-d967-411e-a953-2be52a3b7028     1
# 1081318  fffe698b-d967-411e-a953-2be52a3b7028     2
# 1081319  fffe698b-d967-411e-a953-2be52a3b7028     3
# 1081320  fffe698b-d967-411e-a953-2be52a3b7028     4
# 1081321  fffe698b-d967-411e-a953-2be52a3b7028     5
# 1081322  fffe698b-d967-411e-a953-2be52a3b7028     6
# 1081323  fffe698b-d967-411e-a953-2be52a3b7028     7
# 1081324  fffe698b-d967-411e-a953-2be52a3b7028     8
# 1081325  fffe698b-d967-411e-a953-2be52a3b7028     9
# 1081326  fffe698b-d967-411e-a953-2be52a3b7028     9
# 1081327  fffe7d78-edba-47b6-b162-bc5690d399a2     1
# 1081328  fffe7d78-edba-47b6-b162-bc5690d399a2     2
# 1081329  fffe7d78-edba-47b6-b162-bc5690d399a2     3
# 1081330  fffe7d78-edba-47b6-b162-bc5690d399a2     4
# 1081331  fffe7d78-edba-47b6-b162-bc5690d399a2     5
# 1081332  fffe7d78-edba-47b6-b162-bc5690d399a2     6
# 1081333  fffe7d78-edba-47b6-b162-bc5690d399a2     7
# 1081334  fffe7d78-edba-47b6-b162-bc5690d399a2     8
# 1081335  fffe7d78-edba-47b6-b162-bc5690d399a2     9
# 1081336  fffe7d78-edba-47b6-b162-bc5690d399a2    10
#
#                                                      title
# 0                    UK consumer price inflation: Dec 2017
# 1        FOI responses published by MOD: week commencin...
# 2        FOI responses published by MOD: week commencin...
# 3        FOI responses published by MOD: week commencin...
# 4        FOI responses published by MOD: week commencin...
# 5        FOI responses published by MOD: week commencin...
# 6        FOI responses published by MOD: week commencin...
# 7        FOI responses published by MOD: week commencin...
# 8        FOI responses published by MOD: week commencin...
# 9        FOI responses published by MOD: week commencin...
# 10       FOI responses published by MOD: week commencin...
# 11                                                 unknown
# 12                                                 unknown
# 13                                                 unknown
# 14                                                 unknown
# 15                                                 unknown
# 16                                                 unknown
# 17                                                 unknown
# 18                                                 unknown
# 19                                                 unknown
# 20                                                 unknown
# 21                                                 unknown
# 22                                                 unknown
# 23                                                 unknown
# 24                                                 unknown
# 25                                                 unknown
# 26                                                 unknown
# 27                                                 unknown
# 28                                                 unknown
# 29                                                 unknown
# ...                                                    ...
# 1081307  Mrs A Garrick v Czajka Properties Ltd: 1801317...
# 1081308  Mrs A Garrick v Czajka Properties Ltd: 1801317...
# 1081309  Mrs A Garrick v Czajka Properties Ltd: 1801317...
# 1081310  Mrs A Garrick v Czajka Properties Ltd: 1801317...
# 1081311  Mrs A Garrick v Czajka Properties Ltd: 1801317...
# 1081312  Mrs A Garrick v Czajka Properties Ltd: 1801317...
# 1081313  Mrs A Garrick v Czajka Properties Ltd: 1801317...
# 1081314  Mrs A Garrick v Czajka Properties Ltd: 1801317...
# 1081315  Mrs A Garrick v Czajka Properties Ltd: 1801317...
# 1081316  Mrs A Garrick v Czajka Properties Ltd: 1801317...
# 1081317              SP11 7EF: Environmental permit issued
# 1081318              SP11 7EF: Environmental permit issued
# 1081319              SP11 7EF: Environmental permit issued
# 1081320              SP11 7EF: Environmental permit issued
# 1081321              SP11 7EF: Environmental permit issued
# 1081322              SP11 7EF: Environmental permit issued
# 1081323              SP11 7EF: Environmental permit issued
# 1081324              SP11 7EF: Environmental permit issued
# 1081325              SP11 7EF: Environmental permit issued
# 1081326              SP11 7EF: Environmental permit issued
# 1081327        Cross Country 2016 rail franchise agreement
# 1081328        Cross Country 2016 rail franchise agreement
# 1081329        Cross Country 2016 rail franchise agreement
# 1081330        Cross Country 2016 rail franchise agreement
# 1081331        Cross Country 2016 rail franchise agreement
# 1081332        Cross Country 2016 rail franchise agreement
# 1081333        Cross Country 2016 rail franchise agreement
# 1081334        Cross Country 2016 rail franchise agreement
# 1081335        Cross Country 2016 rail franchise agreement
# 1081336        Cross Country 2016 rail franchise agreement
#
# [1081337 rows x 9 columns]

# %%
top_10_df.shape
# Out:
# (1081337, 9)

# %%
top_10_df.query('base_path != "unknown"').shape
# Out:
# (907645, 9)

# %% [markdown]
# # Get related links for colleagues to review

# %% [markdown]
# ## Top 10 links for the 200 pages with the most co-occurrences (as page 1 in a page1->page2 pair)

# %%
grouped_df = df_llr_recs.groupby('page_1').max()

# %%
top_200_pages = grouped_df.sort_values('page_1_occurrences', ascending=False).reset_index()['page_1'][:200].tolist()

# %%
def in_top_200(page):
    return page in top_200_pages

# %%
top_10_df['is_top_200'] = top_10_df['page'].map(in_top_200)

# %%
top_10_df[top_10_df['is_top_200']][
    ['title', 'link_title', 'base_path', 'link_base_path', 'page', 'link',
     'llr_score','rank','co_occurrences'
    ]].to_csv(
    os.path.join(DATA_DIR, 'llr', 
                 'llr_4_top_200_sequenced_filtered20190218_20190310.csv'), index=False)

# %%
top_10_df['page'].nunique()
# Out:
# 146888

# %%
top_10_df.sort_values('llr_score', ascending=True).head(1000)
# Out:
#                                                  base_path  co_occurrences  \
# 557857   www.gov.uk/government/publications/help-to-buy...               1
# 333688   www.gov.uk/government/publications/the-nationa...               1
# 956012   www.gov.uk/government/news/click-to-accept-jur...               1
# 161476   www.gov.uk/government/news/air-safety-informat...               1
# 422065   www.gov.uk/government/news/francis-report-on-m...               1
# 157361   www.gov.uk/government/publications/dwp-debt-ma...               1
# 339275   www.gov.uk/government/news/functions-of-clinic...               1
# 925886   www.gov.uk/government/news/gp-indemnity-develo...               1
# 161461   www.gov.uk/government/publications/simple-paym...               1
# 265108                                             unknown               1
# 294918   www.gov.uk/government/publications/lawful-deve...               1
# 299111   www.gov.uk/government/publications/warcop-acce...               1
# 552804   www.gov.uk/government/news/dvla-personalised-r...               1
# 610149   www.gov.uk/government/publications/sfa-compens...               1
# 636404   www.gov.uk/government/news/identifying-phishin...               1
# 240290   www.gov.uk/government/news/merger-of-credit-sc...               1
# 761365   www.gov.uk/government/statistics/cold-weather-...               1
# 896929                                             unknown               1
# 1028264  www.gov.uk/government/news/government-introduc...               1
# 169889   www.gov.uk/government/news/outbreaks-of-koi-he...               1
# 960366   www.gov.uk/government/case-studies/rise-to-the...               1
# 400599   www.gov.uk/government/news/free-childcare-exte...               1
# 440415   www.gov.uk/government/news/funding-boost-for-p...               1
# 134444   www.gov.uk/government/publications/tampon-tax-...               1
# 557856   www.gov.uk/government/publications/help-to-buy...               1
# 119682   www.gov.uk/government/news/dont-forget-to-take...               1
# 557856   Help to Buy (equity loan): participation and r...       False
# 119682   Don’t forget to take ID to vote in five pilot ...       False
# 739660                  Lwfans Gofalwr: hysbysu newidiadau       False
# 440556   ‘Francis Effect’ on NHS care one year on from ...       False
# 364019   Housing Benefit subsidy in temporary accommoda...       False
# 660016   SSAC Occasional Paper 18: Decision making and ...       False
# ...                                                    ...         ...
# 589100         Shared Workspace: add a new customer member       False
# 555445                                             unknown       False
# 351727              A summary of the health harms of drugs       False
# 182257     Cyber Security Regulation and Incentives Review       False
# 394283   Consul in Italy warns Brits not to let their p...       False
# 565485          Section 251 budget workbooks: 2014 to 2015       False
# 426662   "Don’t let a lost passport spoil your Christma...       False
# 325529                 Do you know where your passport is?       False
# 302572                         State aid: beginner's guide       False
# 340021   NHS Business Services Authority (Amendment) Di...       False
# 356505            Judicial salaries and fees: 2011 to 2012       False
# 989595                                             unknown       False
# 27550                                              unknown       False
# 328458   Openness and accountability in local pay: supp...       False
# 772226   Personal pensions: contribution and tax relief...       False
# 704576   Self-employment Working Tax Credits claimant s...       False
# 352769   Diabetes type 1 in childhood. National Service...       False
# 405684     Help to Work scheme announced by the government       False
# 755382   Death registrations in England and Wales, summ...       False
# 1070029  IESD: voluntary sector funding for health and ...       False
# 649279                                             unknown       False
# 195398            Mr S Hussain v Rasassi Ltd: 2417072/2018       False
# 378292   Incapacity benefits face-to-face assessments, ...       False
# 934696         Synopsis of causation: compartment syndrome       False
# 706447   Darlington borough council local authority sch...       False
# 994575           Benefit sanctions statistics to June 2017       False
# 567973   Payment by Results: Review of Mental Health ca...       False
# 290359   Disabled Facilities Grant allocation methodolo...       False
# 342420                                             unknown       False
# 301398             Changes to rest and recuperation policy       False
#
# [1000 rows x 10 columns]

# %%
top_10_df.shape
# Out:
# (1081337, 10)

# %%
top_10_df['base_path'].nunique()
# Out:
# 122014

# %%
top_10_df[top_10_df['co_occurrences'] > 1].shape
# Out:
# (427877, 10)

# %%
top_10_df[top_10_df['co_occurrences'] > 1]['base_path'].nunique()
# Out:
# 61607

# %%
top_10_df[top_10_df['co_occurrences'] > 2]['base_path'].nunique()
# Out:
# 42375

# %% [markdown]
# ## Calculate `ln(llr_score)` as it's easier to interpret

# %%
top_10_df['ln_llr_score'] = top_10_df['llr_score'].map(math.log)

# %%
top_10_df.head()
# Out:
#                                            base_path  co_occurrences  \
# 0  www.gov.uk/government/statistics/uk-consumer-p...               1
# 1  www.gov.uk/government/publications/foi-respons...               1
# 2  www.gov.uk/government/publications/foi-respons...               1
# 3  www.gov.uk/government/publications/foi-respons...               1
# 4  www.gov.uk/government/publications/foi-respons...               1
#
#                                    link  \
# 0  8ec6ea6e-a259-459a-9e5e-ffab399a2e2e
# 1  f79797b8-93a8-4826-a3fa-91488bfbb73d
# 2  60556764-7631-11e4-a3cb-005056011aef
# 3  bd3dad18-b6ed-4f4c-b2d4-1cd4caa9faa8
# 4  5fe61962-7631-11e4-a3cb-005056011aef
#
#                                       link_base_path  \
# 0                               www.gov.uk/tax-codes
# 1  www.gov.uk/government/publications/foi-respons...
# 2  www.gov.uk/government/publications/foi-respons...
# 3  www.gov.uk/government/publications/foi-respons...
# 4  www.gov.uk/government/publications/foi-respons...
#
#                                           link_title     llr_score  \
# 0                                          Tax codes  7.788324e+08
# 1  FOI responses published by MOD: week commencin...  1.272172e+09
# 2  FOI responses released by MOD: week commencing...  1.266232e+09
# 3  FOI responses published by MOD: week commencin...  1.263362e+09
# 4  FOI responses released by MOD: week commencing...  1.263362e+09
#
#                                    page  rank  \
# 0  00015d3f-e7d9-48e8-95ff-ac3f7fa07be3     1
# 1  000227a8-f0d2-417d-8ce4-27a18d62d442     1
# 2  000227a8-f0d2-417d-8ce4-27a18d62d442     2
# 3  000227a8-f0d2-417d-8ce4-27a18d62d442     3
# 4  000227a8-f0d2-417d-8ce4-27a18d62d442     3
#
#                                                title  is_top_200  ln_llr_score
# 0              UK consumer price inflation: Dec 2017       False     20.473306
# 1  FOI responses published by MOD: week commencin...       False     20.963991
# 2  FOI responses published by MOD: week commencin...       False     20.959311
# 3  FOI responses published by MOD: week commencin...       False     20.957042
# 4  FOI responses published by MOD: week commencin...       False     20.957042

# %%
top_10_df.ln_llr_score.describe()
# Out:
# count    1.081337e+06
# mean     2.154350e+01
# std      1.038929e+00
# min      1.639084e+01
# 25%      2.096136e+01
# 50%      2.116171e+01
# 75%      2.180348e+01
# max      3.200472e+01
# Name: ln_llr_score, dtype: float64

# %%
top_10_df[top_10_df['co_occurrences'] == 1].shape
# Out:
# (653460, 11)

# %%
top_10_df[top_10_df['co_occurrences'] > 1].sort_values('llr_score', ascending=True)
# Out:
#                                                  base_path  co_occurrences  \
# 624430                                             unknown               2
# 580875   www.gov.uk/government/publications/vat-applica...               2
# 977232                                             unknown               2
# 170847   www.gov.uk/government/news/dwp-announces-extra...               2
# 378524   www.gov.uk/government/news/change-to-passport-...               2
# 402532   www.gov.uk/government/news/69-million-more-for...               2
# 561367                                             unknown               2
# 478773   www.gov.uk/government/publications/updated-vis...               2
# 879421   www.gov.uk/government/news/dvla-and-mib-announ...               2
# 374557   www.gov.uk/government/news/online-payment-opti...               2
# 427559   www.gov.uk/government/news/important-change-to...               2
# 417569   www.gov.uk/government/publications/pay-your-vi...               2
# 554189   www.gov.uk/government/publications/self-assess...               2
# 376108   www.gov.uk/government/news/universal-credit-la...               2
# 779098                                             unknown               2
# 384559   www.gov.uk/government/news/home-office-introdu...               2
# 311141   www.gov.uk/government/publications/acceptance-...               2
# 576563   www.gov.uk/government/publications/no-more-tax...               2
# 427680   www.gov.uk/government/news/self-assessment-new...               2
# 384211   www.gov.uk/government/publications/jobseekers-...               2
# 373806   www.gov.uk/government/publications/applying-fo...               2
# 373655   www.gov.uk/government/publications/collective-...               2
# 496554                                             unknown               2
# 434550   www.gov.uk/government/publications/tuberculosi...               2
# 503394   www.gov.uk/government/news/changes-to-the-uk-v...               2
# 448435   www.gov.uk/government/news/online-vehicle-serv...               2
# 474492   www.gov.uk/government/news/important-informati...               2
# 513789   www.gov.uk/government/publications/guidance-on...               2
# 413994   www.gov.uk/government/news/tuberculosis-testin...               2
# 496554                     www.gov.uk/apply-renew-passport
# 434550                            www.gov.uk/check-uk-visa
# 503394                  www.gov.uk/apply-to-come-to-the-uk
# 448435        www.gov.uk/get-vehicle-information-from-dvla
# 474492                    www.gov.uk/standard-visitor-visa
# 513789                    www.gov.uk/standard-visitor-visa
# 413994                            www.gov.uk/check-uk-visa
# 371690     www.gov.uk/log-in-register-hmrc-online-services
# ...                                                    ...
# 891000                  www.gov.uk/change-name-address-v5c
# 625144   www.gov.uk/government/publications/self-assess...
# 25820                               www.gov.uk/vehicle-tax
# 712989                           www.gov.uk/driving-abroad
# 69285    www.gov.uk/guidance/job-expenses-for-uniforms-...
# 1021598  www.gov.uk/guidance/uk-nationals-travelling-to...
# 797509                     www.gov.uk/photos-for-passports
# 141090                                www.gov.uk/tax-codes
# 1047444                 www.gov.uk/30-hours-free-childcare
# 1064303                www.gov.uk/vehicle-tax-direct-debit
# 1016495               www.gov.uk/tell-dvla-changed-address
# 25819                         www.gov.uk/check-mot-history
# 842355                         www.gov.uk/universal-credit
# 851436      www.gov.uk/settled-status-eu-citizens-families
# 43298                                              unknown
# 881691                www.gov.uk/check-driving-information
# 627416                                             unknown
# 831321                              www.gov.uk/vehicle-tax
# 784731   www.gov.uk/guidance/international-driving-perm...
# 827605                         www.gov.uk/check-mot-status
# 1064302                                            unknown
# 72621                   www.gov.uk/research-family-history
# 970855                    www.gov.uk/standard-visitor-visa
# 881690                                             unknown
# 956712                www.gov.uk/sign-in-childcare-account
# 827604                        www.gov.uk/check-vehicle-tax
# 971531                        www.gov.uk/check-mot-history
# 777038     www.gov.uk/log-in-register-hmrc-online-services
# 1064301                       www.gov.uk/check-vehicle-tax
# 890999           www.gov.uk/change-address-driving-licence
#
#                                                 link_title     llr_score  \
# 624430                      Apply online for a UK passport  2.282573e+08
# 580875                  HMRC services: sign in or register  2.638685e+08
# 977232            Sign in to your Universal Credit account  2.856630e+08
# 170847                            Check your State Pension  3.139430e+08
# 378524                      Apply online for a UK passport  3.173728e+08
# 402532                                    Universal Credit  3.388015e+08
# 561367                      Apply online for a UK passport  3.479888e+08
# 478773                              Standard Visitor visa   3.558906e+08
# 879421                         Check if a vehicle is taxed  3.561401e+08
# 374557                              Standard Visitor visa   3.833804e+08
# 427559                                       Passport fees  3.900339e+08
# 417569                              Standard Visitor visa   3.933972e+08
# 554189   Register for and file your Self Assessment tax...  3.934668e+08
# 376108            Sign in to your Universal Credit account  3.937615e+08
# 779098                                             unknown  3.991155e+08
# 384559                              Standard Visitor visa   4.039037e+08
# 311141                                Benefits calculators  4.106893e+08
# 576563                                    Tax your vehicle  4.147128e+08
# 427680                  HMRC services: sign in or register  4.163412e+08
# 384211                                    Universal Credit  4.191307e+08
# 373806                                Get a passport photo  4.222509e+08
# 373655                Renew or replace your adult passport  4.243964e+08
# 496554                      Apply online for a UK passport  4.272591e+08
# 434550                         Check if you need a UK visa  4.417462e+08
# 503394               Applying for a visa to come to the UK  4.449875e+08
# 448435                   Get vehicle information from DVLA  4.468409e+08
# 474492                              Standard Visitor visa   4.518494e+08
# 427559   Important change to passport service for Briti...       False
# 417569           Pay your visa application fee in Thailand       False
# 554189   Self Assessment: penalty for a late partnershi...       False
# 376108             Universal Credit launches in Manchester       False
# 779098                                             unknown       False
# 384559   Home Office Introduces a New Fast Track Visa S...       False
# 311141   Acceptance and rejection figures for the Warm ...       False
# 576563    One month on since the abolition of the tax disc       False
# 427680     Self Assessment newcomers urged to register now       False
# 384211              Jobseeker's Allowance for lone parents       False
# 373806                             Applying for a passport       False
# 373655                                Collective passports       False
# 496554                                             unknown       False
# 434550   Tuberculosis test for a UK visa: clinics in Mo...       False
# 503394   Changes to the UK Visa Application Process in ...       False
# 448435              Online vehicle services get a makeover       False
# 474492   Important information for UK Visa applicants i...       False
# 513789   Guidance on the main immigration routes for ar...       False
# 413994                     Tuberculosis testing in Bolivia       False
# 371690   Frequently asked questions on the closure of t...       False
# ...                                                    ...         ...
# 891000                    Tell DVLA you've changed address        True
# 625144   Register for and file your Self Assessment tax...        True
# 25820                          Check if a vehicle is taxed        True
# 712989   International driving permits for UK drivers f...        True
# 69285               Claim tax relief for your job expenses        True
# 1021598                                            unknown        True
# 797509                      Apply online for a UK passport        True
# 141090                                  Claim a tax refund        True
# 1047444          Get 30 hours free childcare: step by step        True
# 1064303                                   Tax your vehicle        True
# 1016495         Change the address on your driving licence        True
# 25819                          Check if a vehicle is taxed        True
# 842355            Sign in to your Universal Credit account        True
# 851436   Continue to live in the UK after it leaves the EU        True
# 43298                         Child Benefit tax calculator        True
# 881691      View or share your driving licence information        True
# 627416                                    Pay a court fine       False
# 831321                                             unknown        True
# 784731             Prepare to drive in the EU after Brexit        True
# 827605                  Check the MOT history of a vehicle        True
# 1064302                                   Tax your vehicle        True
# 72621    Order a copy of a birth, death or marriage cer...        True
# 970855                         Check if you need a UK visa        True
# 881690      View or share your driving licence information        True
# 956712                Get Tax-Free Childcare: step by step        True
# 827604                  Check the MOT history of a vehicle        True
# 971531                   Check the MOT status of a vehicle        True
# 777038   Government Gateway replacement: services that ...        True
# 1064301                                   Tax your vehicle        True
# 890999                    Tell DVLA you've changed address        True
#
#          ln_llr_score
# 624430      19.245984
# 580875      19.390961
# 977232      19.470323
# 170847      19.564722
# 378524      19.575588
# 402532      19.640925
# 561367      19.667681
# 478773      19.690134
# 879421      19.690835
# 374557      19.764538
# 427559      19.781744
# 417569      19.790330
# 554189      19.790507
# 376108      19.791256
# 779098      19.804761
# 384559      19.816687
# 311141      19.833348
# 576563      19.843097
# 427680      19.847016
# 384211      19.853693
# 373806      19.861110
# 373655      19.866178
# 496554      19.872901
# 434550      19.906246
# 503394      19.913557
# 448435      19.917713
# 474492      19.928860
# 513789      19.928860
# 413994      19.944430
# 371690      19.946896
# ...               ...
# 891000      30.446103
# 625144      30.466609
# 25820       30.466857
# 712989      30.474881
# 69285       30.489372
# 1021598     30.495867
# 797509      30.501620
# 141090      30.533830
# 1047444     30.542266
# 1064303     30.566724
# 1016495     30.588290
# 25819       30.667975
# 842355      30.671859
# 851436      30.693444
# 43298       30.704578
# 881691      30.704737
# 627416      30.709288
# 831321      30.778760
# 784731      30.844546
# 827605      30.909478
# 1064302     30.975004
# 72621       31.090971
# 970855      31.197871
# 881690      31.330718
# 956712      31.421625
# 827604      31.461697
# 971531      31.468501
# 777038      31.498519
# 1064301     31.796282
# 890999      32.004724
#
# [427877 rows x 11 columns]

# %%
top_10_df.co_occurrences.describe()
# Out:
# count    1.081337e+06
# mean     2.118323e+01
# std      5.042700e+02
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      3.000000e+00
# max      1.847650e+05
# Name: co_occurrences, dtype: float64

# %% [markdown]
# ## Get top 7 links for each page, where co_occurrences > 1, or co_occurrences = 1
# Save down these two things to show that co_occurrences = 1 lead to some bad links

# %%
top_7_df = get_top_n(related_links, n=7)

# %%
top_7_df[(top_7_df['co_occurrences'] > 1) ].shape
# Out:
# (334638, 9)

# %%
top_7_df[(top_7_df['co_occurrences'] > 1) & (top_7_df['base_path'] != 'unknown')].shape
#          (top_7_df['co_occurrences'] < 1000)]
# Out:
# (280220, 9)

# %%
top_7_df[(top_7_df['co_occurrences'] > 1) & (top_7_df['co_occurrences'] < 10)].shape
# Out:
# (251551, 9)

# %%
top_7_df[(top_7_df['co_occurrences'] > 1) & (top_7_df['base_path'] != 'unknown')][['title', 'link_title', 'base_path', 'link_base_path', 
     'llr_score','co_occurrences'
    ]].to_csv(
    os.path.join(DATA_DIR, 'llr', 
                 'llr_4_top_7_coocurrence_gt_1_sequenced_filtered20190218_20190310.csv'), index=False)

# %%
top_7_df[top_7_df['co_occurrences'] == 1].sort_values('llr_score', ascending=False)[
    ['title', 'link_title', 'base_path', 'link_base_path', 'page', 'link',
     'llr_score','rank','co_occurrences'
    ]].head(100).to_csv(
    os.path.join(DATA_DIR, 'llr', 
                 'llr_4_top_7_single_coocurrence_highest_scores_20190218_20190310.csv'), index=False)

# %%
top_7_df[top_7_df['co_occurrences'] == 1].sort_values('llr_score', ascending=True)[
    ['title', 'link_title', 'base_path', 'link_base_path', 'page', 'link',
     'llr_score','rank','co_occurrences'
    ]].head(100).to_csv(
    os.path.join(DATA_DIR, 'llr', 
                 'llr_4_top_7_single_coocurrence_lowest_scores_20190218_20190310.csv'), index=False)

# %%
top_7_df[(top_7_df['co_occurrences'] > 1)]['page'].nunique()
# Out:
# 72213

# %%
top_7_df[(top_7_df['co_occurrences'] > 1)]['base_path'].nunique()
# Out:
# 61559

# %% [markdown]
# ## Get top 10 links per page for the most popular pages based on some GA data
# i.e. get the top 10 links per page for a specified list of base paths

# %%
top_pages_GA = pd.read_csv(os.path.join(DATA_DIR, 'metadata', 'top_pages.csv'))

# %%
top_pages = top_pages_GA['Page'].tolist()

# %%
def is_top_page(pagepath):
    return pagepath in top_pages

# %%
top_10_df['is_top_page'] = top_10_df['base_path'].map(is_top_page)

# %%
top_10_df[top_10_df['is_top_page']].shape
# Out:
# (1470, 12)

# %%
top_10_df[top_10_df['is_top_page']][
    ['title', 'link_title', 'base_path', 'link_base_path', 'page', 'link',
     'llr_score','rank','co_occurrences'
    ]].to_csv(
    os.path.join(DATA_DIR, 'llr', 
                 'llr_4_top_10_top_GA_pages_20190218_20190310.csv'), index=False)
